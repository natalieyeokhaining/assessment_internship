# %%
from ultralytics import YOLO
model = YOLO('yolo11n-pose.pt')

results = model.track(source="segi Fresh fish 1.mp4", show=True, save=True)
# Out:
# WARNING ⚠️
# Inference results will accumulate in RAM unless `stream=True` is passed, which can cause out-of-memory errors for large
# sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs
#
# video 1/1 (frame 1/2387) /Users/natyeo/Documents/infomina/python-lab/jupyter_code/segi Fresh fish 1.mp4: 384x640 3 persons, 94.8ms
# video 1/1 (frame 2/2387) /Users/natyeo/Documents/infomina/python-lab/jupyter_code/segi Fresh fish 1.mp4: 384x640 3 persons, 250.2ms
# video 1/1 (frame 3/2387) /Users/natyeo/Documents/infomina/python-lab/jupyter_code/segi Fresh fish 1.mp4: 384x640 3 persons, 180.1ms
# ...
