# %%
from ultralytics import YOLO
model = YOLO('yolo11n-pose.pt')

results = model.track(source="Segi Fresh 9.png", show=True, save=True)
# Out:
# image 1/1 /Users/natyeo/Documents/infomina/python-lab/jupyter_code/Segi Fresh 9.png: 384x640 2 persons, 84.7ms
# Speed: 10.9ms preprocess, 84.7ms inference, 13.4ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to /Users/natyeo/Documents/infomina/python-lab/runs/pose/track5
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
from ultralytics import YOLO
model = YOLO('yolo11n-pose.pt')

results = model.track(source="Segi Fresh_8.png", show=True, save=True)
# Out:
# image 1/1 /Users/natyeo/Documents/infomina/python-lab/jupyter_code/Segi Fresh_8.png: 384x640 4 persons, 119.1ms
# Speed: 9.6ms preprocess, 119.1ms inference, 12.7ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to /Users/natyeo/Documents/infomina/python-lab/runs/pose/track4
